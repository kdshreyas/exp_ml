# %% [markdown]
# <a href="https://colab.research.google.com/github/kdshreyas/exp_ml/blob/master/data_pre_processiong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
path = r'/content/drive/MyDrive/Machine Learning/Machine Learning A-Z (Codes and Datasets)/Part 1 - Data Preprocessing/Section 2 -------------------- Part 1 - Data Preprocessing --------------------/Python'
os.listdir(path)
# Out:
# ['Data.csv',
#  'data_preprocessing_template.ipynb',
#  'data_preprocessing_template.py',
#  'data_preprocessing_tools.py',
#  'data_preprocessing_tools.ipynb',
#  '.DS_Store']

# %%
os.chdir(path)
os.getcwd()
# Out:
# '/content/drive/MyDrive/Machine Learning/Machine Learning A-Z (Codes and Datasets)/Part 1 - Data Preprocessing/Section 2 -------------------- Part 1 - Data Preprocessing --------------------/Python'

# %%
import pandas as pd
df = pd.read_csv('Data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
import numpy as np

# %%
y = df.iloc[:,-1].values

# %%
X = df.iloc[:,:-1].values

# %%
y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#       dtype=object)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])

# %%
df.loc[:,'Age'] = imputer.fit_transform(df[['Age']])
df.loc[:,'Salary'] = imputer.fit_transform(df[['Salary']])

# %%
df.loc[:,'Salary'] = imputer.fit_transform(df[['Salary']])

# %%
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
import pandas as pd
df1 = pd.read_csv('Data.csv')

# %%
df1
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    44.000000
# 1    27.000000
# 2    30.000000
# 3    38.000000
# 4    40.000000
# 5    35.000000
# 6    38.777778
# 7    48.000000
# 8    50.000000
# 9    37.000000
# Name: Age, dtype: float64

# %%
for i in df1.columns[df1.isnull().any(axis=0)]:   #---Applying Only on variables with NaN values
    df[i].fillna(df[i].mean(),inplace=True)
    print(i)
# Out:
# Age
# Salary

# %%
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes
